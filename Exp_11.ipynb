# %%
import pandas as pd
import numpy as np

df = pd.read_csv("car_evaluation.csv")
df.head(4)
# Out:
#   buy_price maint_cost doors person boot_space safety  class
# 0     vhigh      vhigh     2      2      small    low  unacc
# 1     vhigh      vhigh     2      2      small    med  unacc
# 2     vhigh      vhigh     2      2      small   high  unacc
# 3     vhigh      vhigh     2      2        med    low  unacc

# %%
df.isna().sum()
# Out:
# buy_price     0
# maint_cost    0
# doors         0
# person        0
# boot_space    0
# safety        0
# class         0
# dtype: int64

# %%
df['doors'].max()
# Out:
# '5more'

# %%
df['class'].value_counts()
# Out:
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64

# %%
df['buy_price'].value_counts()
# Out:
# vhigh    432
# med      432
# high     432
# low      432
# Name: buy_price, dtype: int64

# %%
df['maint_cost'].value_counts()
# Out:
# vhigh    432
# med      432
# high     432
# low      432
# Name: maint_cost, dtype: int64

# %%
df['doors'].value_counts()
# Out:
# 3        432
# 5more    432
# 2        432
# 4        432
# Name: doors, dtype: int64

# %%
df['person'].value_counts()
# Out:
# 2       576
# more    576
# 4       576
# Name: person, dtype: int64

# %%
df.columns
# Out:
# Index(['buy_price', 'maint_cost', 'doors', 'person', 'boot_space', 'safety',
#        'class'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in data.columns[:-1]:
    data[col]=le.fit_transform(data[col])

# %%
df
# Out:
#       buy_price  maint_cost  doors  person  boot_space  safety  class
# 0             3           3      0       0           2       1  unacc
# 1             3           3      0       0           2       2  unacc
# 2             3           3      0       0           2       0  unacc
# 3             3           3      0       0           1       1  unacc
# 4             3           3      0       0           1       2  unacc
# ...         ...         ...    ...     ...         ...     ...    ...
# 1723          1           1      3       2           1       2   good
# 1724          1           1      3       2           1       0  vgood
# 1725          1           1      3       2           0       1  unacc
# 1726          1           1      3       2           0       2   good
# 1727          1           1      3       2           0       0  vgood
#
# [1728 rows x 7 columns]

# %%
max_value=df['buy_price'].max()
print(max_value)
min_value=df['buy_price'].min()
print(min_value)
# Out:
# 3
# 0

# %%
max_value=df['maint_cost'].max()
print(max_value)
min_value=df['maint_cost'].min()
print(min_value)
# Out:
# 3
# 0

# %%
X=df[['buy_price','maint_cost','doors','person','boot_space','safety']]
y=df[['class']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

best_accuracy=0
best_n_components=0

for n_components in range(2,6):
    pca=PCA(n_components=n_components)
    X_train_pca=pca.fit_transform(X_train)
    X_test_pca=pca.fit_transform(X_test)

    clf=RandomForestClassifier(random_state=42)
    clf.fit(X_train_pca,y_train)

    y_pred=clf.predict(X_test_pca)
    accuracy=accuracy_score(y_test,y_pred)

    print(f"Number of PCA components: {n_components},Accuracy: {accuracy}")

    if accuracy>best_accuracy:
        best_accuracy=accuracy
        best_n_components=n_components

print(f"Best number of PCA components: {best_n_components},Best_accuracy: {best_accuracy}")
# Out:
# /tmp/ipykernel_7661/111854838.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train_pca,y_train)
# /tmp/ipykernel_7661/111854838.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train_pca,y_train)
# Number of PCA components: 2,Accuracy: 0.649325626204239
# Number of PCA components: 3,Accuracy: 0.6859344894026975
# /tmp/ipykernel_7661/111854838.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train_pca,y_train)
# /tmp/ipykernel_7661/111854838.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...
